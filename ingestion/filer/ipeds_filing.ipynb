# %% [markdown]
# # Summary
#
# Load, transform and save IPEDS files to Google Cloud Storage.

# %% [markdown]
# ## Import libraries

# %%
import sys

sys.path.insert(0, "file_tools/")
import ipeds_csv_ingester as ici

sys.path.append("../../interface/utils")
import gcp_tools as gct
from authentication import ApiAuthentication

# Set environment variables
dotenv_path = "../../data/environment"
api_configs = ApiAuthentication(dotenv_path=dotenv_path)
api_configs.set_environ_variables()

# %% [markdown]
# ## Read and transform IPEDS files

# %%
files = ici.IpedsCsvIngester()
