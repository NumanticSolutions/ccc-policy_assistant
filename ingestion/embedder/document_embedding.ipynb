# %% [markdown]
# # Summary
#
# Notebook to run the embedding process for multiple documents

# %%
import os.path
import sys

sys.path.insert(0, "embed_tools/")
import document_embedder as de

# %% [markdown]
# ## Test

# %%
# Set paths

# Create embedding object
embed_loader = de.EmbedDocuments()

# # Read input files
# embed_loader.get_input_filenames()
#
# # Read crawl data
# embed_loader.read_crawl_data()
#
# # Embed
# embed_loader.embed()

# Copy Embeddings to GCS
embed_loader.copy_embeddings_to_gcs()
# Out:
# Uploaded /Users/stephengodfrey/OneDrive - numanticsolutions.com/Engagements/Projects/ccc_policy_assistant/data/ccc-chromadb-vai-2/chroma.sqlite3 to gs://ccc-chromadb-vai-2/chroma.sqlite3
# Uploaded /Users/stephengodfrey/OneDrive - numanticsolutions.com/Engagements/Projects/ccc_policy_assistant/data/ccc-chromadb-vai-2/7553f5e6-0521-4d13-82c7-7af306bfe444/data_level0.bin to gs://ccc-chromadb-vai-2/7553f5e6-0521-4d13-82c7-7af306bfe444/data_level0.bin
# Uploaded /Users/stephengodfrey/OneDrive - numanticsolutions.com/Engagements/Projects/ccc_policy_assistant/data/ccc-chromadb-vai-2/7553f5e6-0521-4d13-82c7-7af306bfe444/length.bin to gs://ccc-chromadb-vai-2/7553f5e6-0521-4d13-82c7-7af306bfe444/length.bin
# Uploaded /Users/stephengodfrey/OneDrive - numanticsolutions.com/Engagements/Projects/ccc_policy_assistant/data/ccc-chromadb-vai-2/7553f5e6-0521-4d13-82c7-7af306bfe444/link_lists.bin to gs://ccc-chromadb-vai-2/7553f5e6-0521-4d13-82c7-7af306bfe444/link_lists.bin
# Uploaded /Users/stephengodfrey/OneDrive - numanticsolutions.com/Engagements/Projects/ccc_policy_assistant/data/ccc-chromadb-vai-2/7553f5e6-0521-4d13-82c7-7af306bfe444/header.bin to gs://ccc-chromadb-vai-2/7553f5e6-0521-4d13-82c7-7af306bfe444/header.bin
# Uploaded /Users/stephengodfrey/OneDrive - numanticsolutions.com/Engagements/Projects/ccc_policy_assistant/data/ccc-chromadb-vai-2/7553f5e6-0521-4d13-82c7-7af306bfe444/index_metadata.pickle to gs://ccc-chromadb-vai-2/7553f5e6-0521-4d13-82c7-7af306bfe444/index_metadata.pickle

# %%
# embed_loader.input_files.loc[16, "path"]
#
# len(embed_loader.docs)
# idx = 1345
#
# embed_loader.docs[1345].metadata
# # # embed_loader.docs[1345].metadata.get("seed_url")
# #
for doc in embed_loader.docs:
    if doc.metadata.get("source") == "ipeds":
        print(doc)
        print()

# embed_loader.docs[13100]
#
# embed_loader.input_files
# Out:
# page_content='CSV data file name: al2023.csv.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/AL2023.zip', 'input_type': 'al2023.csv', 'ptag_text_len': 2423, 'source': 'ipeds', 'source_idx': 0, 'source_idx_i': 0}
#
# page_content='Overview description of file contents: The Academic Library survey became part of the Integrated Postsecondary Education Data system in collection year 2014-15.   Data include characteristics of the library, collections, expenditures and services. The number of full-time equivalent staff employed by the library were added this fiscal year.  Library data are only applicable for degree-granting institutions.  Degree-granting institutions with total expenditures over $100,000 dollars will have' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/AL2023.zip', 'input_type': 'al2023.csv', 'ptag_text_len': 2423, 'source': 'ipeds', 'source_idx': 0, 'source_idx_i': 1}
#
# page_content='will have expenditure data. In 2016-17 the types of collections was expanded to collect information on physical and electronic serials..' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/AL2023.zip', 'input_type': 'al2023.csv', 'ptag_text_len': 2423, 'source': 'ipeds', 'source_idx': 0, 'source_idx_i': 2}
#
# page_content='Data columns: Unique identification number of the institution, Were annual total library expenses greater than or equal to $100,000, Is the Library collection entirely electronic, Number of physical books, Number of digital/electronic books, Number of digital/electronic databases, Number of physical media, Number of digital/electronic media, Number of physical serials, Number of electronic serials, Total physical library collections (books, media and serials), Total electronic library' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/AL2023.zip', 'input_type': 'al2023.csv', 'ptag_text_len': 2423, 'source': 'ipeds', 'source_idx': 0, 'source_idx_i': 3}
#
# page_content='library collections (books, databases, media and serials), Total library collections (physical and electronic), Total physical library circulations (books and media), Total digital/electronic circulations (books and media), Total library circulations (physical and digital/electronic), Does institution have interlibrary loan services ?, Total interlibrary loans and documents provided to other libraries, Total interlibrary loans and documents received, Does  institution have Library Staff?, Total' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/AL2023.zip', 'input_type': 'al2023.csv', 'ptag_text_len': 2423, 'source': 'ipeds', 'source_idx': 0, 'source_idx_i': 4}
#
# page_content='Total library FTE staff, Librarians FTE staff, Other professional FTE staff, All other paid FTE staff (Except Student Assistants), Student assistants FTE, Number of branches and independent libraries, Total salaries and wages from the library budget, Are staff fringe benefits paid out of the library budget, Total fringe benefits, One-time purchases of books, serial backfiles, and other materials, Ongoing commitments to subscriptions, Other materials/services expenditures, Total' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/AL2023.zip', 'input_type': 'al2023.csv', 'ptag_text_len': 2423, 'source': 'ipeds', 'source_idx': 0, 'source_idx_i': 5}
#
# page_content='Total materials/services expenditures, Preservation services, Other operation and maintenance expenditures, Total operations and maintenance expenditures, Total expenditures (salaries/wages, benefits, materials/services, and operations/maintenance), Salaries/wages, materials/services, and operations/maintenance.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/AL2023.zip', 'input_type': 'al2023.csv', 'ptag_text_len': 2423, 'source': 'ipeds', 'source_idx': 0, 'source_idx_i': 6}
#
# page_content='CSV data file name: c2023dep.csv.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 0}
#
# page_content='Overview description of file contents: This file contains the number of programs offered, by type of program, level of award (certificate or degree) and distance education status.  Program offerings were derived from completions data that were granted between July 1, 2022 and June 30, 2023.  Type of program is categorized according to the 2020 Classification of Instructional Programs (CIP), a detailed coding system for postsecondary instructional programs. The 2010 CIP was used to categorize' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 1}
#
# page_content='programs for Completions data collected from 2009-10 through 2018-19.  Information on the CIP classification taxonomy, including a crosswalk between CIP 2010 and 2020 is available at https://nces.ed.gov/ipeds/cipcode/resources.aspx?y=56 . Beginning in 2019-20, the less than 1-year certificate award level is divided into the following two award levels: certificates of less than 12 weeks and certificates of at least 12 weeks but less than 1 year. More detailed information on distance education' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 2}
#
# page_content='education was also added in 2019-20.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 3}
#
# page_content='This file contains multiple records per institution. Each record is uniquely defined by the variables IPEDS ID (UNITID) and classification of instructional program (CIPCODE).  Each record will contain the total number of programs offered and the total number of programs offered via distance education. Six digit CIPCODE (XX.NNNN) records will identify which award levels are offered and which award levels are offered via distance learning (1=Yes, 0=No). Two digit CIPCODE (XX) summary records will' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 4}
#
# page_content='will contain the number of 6-digit CIPCODES under the  2-digit group that are offered by award level and distance education status and CIPCODE (99)  will contain totals for the institution..' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 5}
#
# page_content='Data columns: Unique identification number of the institution, CIPCODE - 2020 Classification, All award levels - number of programs offered, All award levels - number of programs in a CIP code can be completed entirely via distance education, All award levels - number of programs with some programs in a CIP code can be completed entirely via distance education, Associate's degree - programs offered, Associate's degree - all programs in a CIP code can be completed entirely via distance' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 6}
#
# page_content='distance education, Associate's degree - some programs in a CIP code can be completed entirely via distance education, Bachelor's degree - programs offered, Bachelor's degree - all programs in a CIP code can be completed entirely via distance education, Bachelor's degree - some programs in a CIP code can be completed entirely via distance education, Master's degree - programs offered, Master's degree - all programs in a CIP code can be completed entirely via distance education, Master's degree' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 7}
#
# page_content='degree - some programs in a CIP code can be completed entirely via distance education, Doctor's degree-research/scholarship - programs offered, Doctor's degree-research/scholarship - all programs in a CIP code can be completed entirely via distance education, Doctor's degree-research/scholarship - some programs in a CIP code can be completed entirely via distance education, Doctor's degree-professional practice - programs offered, Doctor's degree-professional practice - all programs in a CIP' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 8}
#
# page_content='in a CIP code can be completed entirely via distance education, Doctor's degree-professional practice - some programs in a CIP code can be completed entirely via distance education, Doctor's degree-other - programs offered, Doctor's degree-other - all programs in a CIP code can be completed entirely via distance education, Doctor's degree-other - some programs in a CIP code can be completed entirely via distance education, Certificates of less than 12 weeks - programs offered, Certificates of' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 9}
#
# page_content='of less than 12 weeks - all programs in a CIP code can be completed entirely via distance education, Certificates of less than 12 weeks - some programs in a CIP code can be completed entirely via distance education, Certificates of at least 12 weeks, but less than 1 year - programs offered, Certificates of at least 12 weeks, but less than 1 year - all programs in a CIP code can be completed entirely via distance education, Certificates of at least 12 weeks, but less than 1 year - some programs' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 10}
#
# page_content='programs in a CIP code can be completed entirely via distance education, Certificates of 1 year, but less than 2 years - programs offered, Certificates of 1 year, but less than 2 years - all programs in a CIP code can be completed entirely via distance education, Certificates of 1 year, but less than 2 years - some programs in a CIP code can be completed entirely via distance education, Certificates of 2 years, but less than 4 years - programs offered, Certificates of 2 years, but less than 4' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 11}
#
# page_content='than 4 years - all programs in a CIP code can be completed entirely via distance education, Certificates of 2 years, but less than 4 years - some programs in a CIP code can be completed entirely via distance education, Postbaccalaureate certificate - programs offered, Postbaccalaureate certificate - all programs in a CIP code can be completed entirely via distance education, Postbaccalaureate certificate - some programs in a CIP code can be completed entirely via distance education,' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 12}
#
# page_content='Post-master's certificate - programs offered, Post-master's certificate - all programs in a CIP code can be completed entirely via distance education, Post-master's certificate - some programs in a CIP code can be completed entirely via distance education.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023DEP.zip', 'input_type': 'c2023dep.csv', 'ptag_text_len': 5425, 'source': 'ipeds', 'source_idx': 1, 'source_idx_i': 13}
#
# page_content='CSV data file name: c2023_a.csv.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_A.zip', 'input_type': 'c2023_a.csv', 'ptag_text_len': 2279, 'source': 'ipeds', 'source_idx': 2, 'source_idx_i': 0}
#
# page_content='Overview description of file contents: This file contains the number of awards by type of program, level of award (certificate or degree), first or second major and by race/ethnicity and gender. Data covers all awards granted between July 1, 2022 and June 30, 2023.  Type of program is categorized according to the 2020 Classification of Instructional Programs (CIP), a detailed coding system for postsecondary instructional programs.  The 2010 CIP was used to categorize programs for Completions' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_A.zip', 'input_type': 'c2023_a.csv', 'ptag_text_len': 2279, 'source': 'ipeds', 'source_idx': 2, 'source_idx_i': 1}
#
# page_content='data collected from 2009-10 through 2018-19.  Information on the CIP classification taxonomy, including a crosswalk between CIP 2010 and 2020 is available at https://nces.ed.gov/ipeds/cipcode/resources.aspx?y=56 . Beginning in  2019-20, the less than 1 year certificate award level is divided into the following two award levels: certificates of less than 12 weeks and certificates of at least 12 weeks but less than 1 year.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_A.zip', 'input_type': 'c2023_a.csv', 'ptag_text_len': 2279, 'source': 'ipeds', 'source_idx': 2, 'source_idx_i': 2}
#
# page_content='This file contains multiple records per institution. Each record is uniquely defined by the variables IPEDS ID (UNITID), classification of instructional program (CIPCODE), first or second major (MAJORNUM) and award level (AWLEVEL).  Each record will contain the total awards,  awards for men and women, and the total awards and awards for men and women for all nine race/ethnicity categories. .' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_A.zip', 'input_type': 'c2023_a.csv', 'ptag_text_len': 2279, 'source': 'ipeds', 'source_idx': 2, 'source_idx_i': 3}
#
# page_content='Data columns: Unique identification number of the institution, CIP Code -  2020 Classification, First or Second Major, Award Level code, Grand total, Grand total men, Grand total women, American Indian or Alaska Native total, American Indian or Alaska Native men, American Indian or Alaska Native women, Asian total, Asian men, Asian women, Black or African American total, Black or African American men, Black or African American women, Hispanic or Latino total, Hispanic or Latino men, Hispanic or' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_A.zip', 'input_type': 'c2023_a.csv', 'ptag_text_len': 2279, 'source': 'ipeds', 'source_idx': 2, 'source_idx_i': 4}
#
# page_content='or Latino women, Native Hawaiian or Other Pacific Islander total, Native Hawaiian or Other Pacific Islander men, Native Hawaiian or Other Pacific Islander women, White total, White men, White women, Two or more races total, Two or more races men, Two or more races women, Race/ethnicity unknown total, Race/ethnicity unknown men, Race/ethnicity unknown women, U.S. Nonresident total, U.S. Nonresident men, U.S. Nonresident women.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_A.zip', 'input_type': 'c2023_a.csv', 'ptag_text_len': 2279, 'source': 'ipeds', 'source_idx': 2, 'source_idx_i': 5}
#
# page_content='CSV data file name: c2023_b.csv.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_B.zip', 'input_type': 'c2023_b.csv', 'ptag_text_len': 2021, 'source': 'ipeds', 'source_idx': 3, 'source_idx_i': 0}
#
# page_content='Overview description of file contents: This file contains the number of students who completed any degree or certificate by race/ethnicity and gender. Data covers all awards granted between July 1, 2022 and June 30, 2023. This file contains one record per institution. Each record is uniquely defined by the variables IPEDS ID (UNITID).  Each record will contain the total number of students,  men and women, and the total number of students for men and women for all nine race/ethnicity categories.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_B.zip', 'input_type': 'c2023_b.csv', 'ptag_text_len': 2021, 'source': 'ipeds', 'source_idx': 3, 'source_idx_i': 1}
#
# page_content='Beginning with 2021-22, variables containing information on students that do not fit the IPEDS binary gender (men/women) categories were available. In 2022-23 institutions were instructed to report these data if the reported value was 5 or more students..' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_B.zip', 'input_type': 'c2023_b.csv', 'ptag_text_len': 2021, 'source': 'ipeds', 'source_idx': 3, 'source_idx_i': 2}
#
# page_content='Data columns: Unique identification number of the institution, Grand total, Grand total men, Grand total women, American Indian or Alaska Native total, American Indian or Alaska Native men, American Indian or Alaska Native women, Asian total, Asian men, Asian women, Black or African American total, Black or African American men, Black or African American women, Hispanic or Latino total, Hispanic or Latino men, Hispanic or Latino women, Native Hawaiian or Other Pacific Islander total, Native' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_B.zip', 'input_type': 'c2023_b.csv', 'ptag_text_len': 2021, 'source': 'ipeds', 'source_idx': 3, 'source_idx_i': 3}
#
# page_content='Native Hawaiian or Other Pacific Islander men, Native Hawaiian or Other Pacific Islander women, White total, White men, White women, Two or more races total, Two or more races men, Two or more races women, Race/ethnicity unknown total, Race/ethnicity unknown men, Race/ethnicity unknown women, U.S. Nonresident total, U.S. Nonresident men, U.S. Nonresident women, Undergraduate gender unknown, Undergraduate another gender, Undergraduate gender unknown and another gender, Graduate gender unknown,' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_B.zip', 'input_type': 'c2023_b.csv', 'ptag_text_len': 2021, 'source': 'ipeds', 'source_idx': 3, 'source_idx_i': 4}
#
# page_content='unknown, Graduate another gender, Graduate gender unknown and another gender, Total gender unknown, Total another gender, Total of gender unknown and  another gender, Total gender reported as one of the mutually exclusive binary categories (Men/Women).' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_B.zip', 'input_type': 'c2023_b.csv', 'ptag_text_len': 2021, 'source': 'ipeds', 'source_idx': 3, 'source_idx_i': 5}
#
# page_content='CSV data file name: c2023_c.csv.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_C.zip', 'input_type': 'c2023_c.csv', 'ptag_text_len': 1477, 'source': 'ipeds', 'source_idx': 4, 'source_idx_i': 0}
#
# page_content='Overview description of file contents: This file contains the number of students receiving a degree or certificate by level of award and by race/ethnicity,  gender and age categories. Data covers awards granted between July 1, 2022 and June 30, 2023. This file contains multiple records per institution. Each record is uniquely defined by the variables IPEDS ID (UNITID) and award level (AWLEVELC).  Each record will contain the total number of students receiving awards;  number of  men and women' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_C.zip', 'input_type': 'c2023_c.csv', 'ptag_text_len': 1477, 'source': 'ipeds', 'source_idx': 4, 'source_idx_i': 1}
#
# page_content='and women receiving awards: number of students receiving awards for all nine race/ethnicity categories; number of students receiving awards are also available for the following age groups: under 18, 18-24, 25-39, 40 and above.  Numbers are not available for combinations of race, gender and age. Beginning with 2019-20, the certificate of less than 1 year was replaced by the following 2 categories: certificates of less than 12 weeks and certificates of at least 12-weeks but less-than 1-year. .' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_C.zip', 'input_type': 'c2023_c.csv', 'ptag_text_len': 1477, 'source': 'ipeds', 'source_idx': 4, 'source_idx_i': 2}
#
# page_content='Data columns: Unique identification number of the institution, Award Level code, Grand total, Grand total men, Grand total women, American Indian or Alaska Native total, Asian total, Black or African American total, Hispanic or Latino total, Native Hawaiian or Other Pacific Islander total, White total, Two or more races total, Race/ethnicity unknown total, U.S. Nonresident total, Ages, under 18, Ages, 18-24, Ages, 25-39, Ages, 40 and above, Age unknown.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/C2023_C.zip', 'input_type': 'c2023_c.csv', 'ptag_text_len': 1477, 'source': 'ipeds', 'source_idx': 4, 'source_idx_i': 3}
#
# page_content='CSV data file name: drval2023.csv.
# Overview description of file contents: Table contains the percent distribution of library collection, by material type and the percent distribution of library expenses, by function and total library expenditures per FTE enrollment. Frequently used derived variables may include data for child campuses derived from allocation factors that are reported by the parent institution. Parent/child indicators can be found in table flags2023..' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVAL2023.zip', 'input_type': 'drval2023.csv', 'ptag_text_len': 1704, 'source': 'ipeds', 'source_idx': 5, 'source_idx_i': 0}
#
# page_content='Data columns: Unique identification number of the institution, Physical books as a percent of the total library collection, Physical media as a percent of the total library collection, Physical serials as a percent of the total library collection, Digital/Electronic books as a percent of the total library collection, Databases as a percent of the total library collection, Digital/Electronic media as a percent of the total library collection, Digital/Electronic serials as a percent of the total' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVAL2023.zip', 'input_type': 'drval2023.csv', 'ptag_text_len': 1704, 'source': 'ipeds', 'source_idx': 5, 'source_idx_i': 1}
#
# page_content='the total library collection, Salaries and wages from the library budget as a percent of total library expenditures, Fringe benefits paid out of the library budget as a percent of total library expenditures, One-time purchases of books, serial backfiles, and other materials as a percent of total library expenditures, Ongoing commitments to subscriptions as a percent of total library expenditures, All other materials/services as a percent of total library expenditures, Total operations and' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVAL2023.zip', 'input_type': 'drval2023.csv', 'ptag_text_len': 1704, 'source': 'ipeds', 'source_idx': 5, 'source_idx_i': 2}
#
# page_content='and maintenance as a percent of total library expenditures, Total library expenditures per FTE, Total library FTE staff,  Librarians FTE staff, Other professional FTE staff, All other paid FTE staff (Except Student Assistants), Student assistants FTE.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVAL2023.zip', 'input_type': 'drval2023.csv', 'ptag_text_len': 1704, 'source': 'ipeds', 'source_idx': 5, 'source_idx_i': 3}
#
# page_content='CSV data file name: drvc2023.csv.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVC2023.zip', 'input_type': 'drvc2023.csv', 'ptag_text_len': 1525, 'source': 'ipeds', 'source_idx': 6, 'source_idx_i': 0}
#
# page_content='Overview description of file contents: Table includes number of degrees or certificates awarded by level of degree/certificate and the number of students receiving a degree/certificate by level of degree/certificate. These derived variables are based on degrees/certificates for first majors.  Frequently used derived variables may include data for child campuses derived from allocation factors that are reported by the parent institution. Parent/child indicators can be found in table flags2022..' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVC2023.zip', 'input_type': 'drvc2023.csv', 'ptag_text_len': 1525, 'source': 'ipeds', 'source_idx': 6, 'source_idx_i': 1}
#
# page_content='Data columns: Unique identification number of the institution, Associate's degree, Bachelor's degree, Master's degree, Doctor's degree - research/scholarship, Doctor's degree - professional practice, Doctor's degree - other, Certificates of less than 1 year, Certificate of less than 12 weeks, Certificate of at least 12 weeks, but less than 1 year, Certificates of 1 but less than 2 years, Certificates of 2 but less than 4 years, Postbaccalaureate certificates, Post-master's certificates, Number' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVC2023.zip', 'input_type': 'drvc2023.csv', 'ptag_text_len': 1525, 'source': 'ipeds', 'source_idx': 6, 'source_idx_i': 2}
#
# page_content='Number of students receiving an Associate's degree, Number of students receiving a Bachelor's degree, Number of students receiving a Master's degree, Number of students receiving a Doctor's degree, Number of students receiving certificates of less than 12 weeks, Number of students receiving certificates of at least 12 weeks, but less than 1 year, Number of students receiving a certificate of 1 but less than 4 years, Number of students receiving a Postbaccalaureate or Post-master's certificate.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVC2023.zip', 'input_type': 'drvc2023.csv', 'ptag_text_len': 1525, 'source': 'ipeds', 'source_idx': 6, 'source_idx_i': 3}
#
# page_content='CSV data file name: drvef122023.csv.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 0}
#
# page_content='Overview description of file contents: This table contains the 12-month unduplicated head count for all students, undergraduate and graduate students. Undergraduate unduplicated headcounts are disaggregated by attendance status and degree/certificate-seeking status.  The total 12-month full-time equivalent enrollment derived from credit/contact hour data is also included in this table. Percentage distributions of unduplicated 12-month enrollment by race/ethnicity and distance education are' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 1}
#
# page_content='are available in this table.  Frequently used derived variables may include data for child campuses derived from allocation factors that are reported by the parent institution. Parent/child indicators can be found in table flags2023..' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 2}
#
# page_content='Data columns: Unique identification number of the institution, 12-month full-time equivalent enrollment, Total 12-month unduplicated headcount, Full-time 12-month unduplicated headcount, Part-time 12-month unduplicated headcount, Undergraduate 12-month unduplicated headcount, First-time degree/certificate-seeking undergraduate 12-month unduplicated headcount, Transfer-in degree/certificate-seeking undergraduate 12-month unduplicated headcount, Continuing degree/certificate-seeking undergraduate' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 3}
#
# page_content='12-month unduplicated headcount, Nondegree/certificate-seeking undergraduate 12-month unduplicated headcount, Graduate 12-month unduplicated headcount, Full-time undergraduate 12-month unduplicated headcount, Full-time first-time degree/certificate-seeking undergraduate 12-month unduplicated headcount, Full-time transfer-in degree/certificate-seeking undergraduate 12-month unduplicated headcount, Full-time continuing degree/certificate-seeking undergraduate 12-month unduplicated headcount,' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 4}
#
# page_content='Full-time nondegree/certificate-seeking undergraduate 12-month unduplicated headcount, Full-time graduate 12-month unduplicated headcount, Part-time undergraduate 12-month unduplicated headcount, Part-time first-time degree/certificate-seeking undergraduate 12-month unduplicated headcount, Part-time transfer-in degree/certificate-seeking undergraduate 12-month unduplicated headcount, Part-time continuing degree/certificate-seeking undergraduate 12-month unduplicated headcount, Part-time' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 5}
#
# page_content='Part-time nondegree/certificate-seeking undergraduate 12-month unduplicated headcount, Part-time graduate 12-month unduplicated headcount, Percent of 12-month unduplicated headcount that are American Indian or Alaska Native, Percent of 12-month unduplicated headcount that are Asian, Percent of 12-month unduplicated headcount that are Black or African American, Percent of 12-month unduplicated headcount that are Hispanic/Latino, Percent of 12-month unduplicated headcount that are Native Hawaiian' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 6}
#
# page_content='Hawaiian or Other Pacific Islander, Percent of 12-month unduplicated headcount that are White, Percent of 12-month unduplicated headcount that are two or more races, Percent of 12-month unduplicated headcount that are race/ethnicity unknown, Percent of 12-month unduplicated headcount that are U.S. Nonresident, Percent of 12-month unduplicated headcount that are women, Percent of undergraduate 12-month unduplicated headcount that are American Indian or Alaska Native, Percent of undergraduate' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 7}
#
# page_content='12-month unduplicated headcount that are Asian, Percent of undergraduate 12-month unduplicated headcount that are Black or African American, Percent of undergraduate 12-month unduplicated headcount that are Hispanic/Latino, Percent of undergraduate 12-month unduplicated headcount that are Native Hawaiian or Other Pacific Islander, Percent of undergraduate 12-month unduplicated headcount that are White, Percent of undergraduate 12-month unduplicated headcount that are two or more races, Percent' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 8}
#
# page_content='Percent of undergraduate 12-month unduplicated headcount that are race/ethnicity unknown, Percent of undergraduate 12-month unduplicated headcount that are U.S. Nonresident, Percent of undergraduate 12-month unduplicated headcount that are women, Percent of graduate 12-month unduplicated headcount that are American Indian or Alaska Native, Percent of graduate 12-month unduplicated headcount that are Asian, Percent of graduate 12-month unduplicated headcount that are Black or African American,' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 9}
#
# page_content='American, Percent of graduate 12-month unduplicated headcount that are Hispanic/Latino, Percent of graduate 12-month unduplicated headcount that are Native Hawaiian or Other Pacific Islander, Percent of graduate 12-month unduplicated headcount that are White, Percent of graduate 12-month unduplicated headcount that are two or more races, Percent of graduate 12-month unduplicated headcount that are race/ethnicity unknown, Percent of graduate 12-month unduplicated headcount that are U.S.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 10}
#
# page_content='are U.S. Nonresident, Percent of graduate 12-month unduplicated headcount that are women, Percent of 12-month unduplicated headcount enrolled exclusively in distance education courses, Percent of 12-month unduplicated headcount enrolled in some but not all distance education courses, Percent of 12-month unduplicated headcount not enrolled in any distance education courses, Percent of undergraduate 12-month unduplicated headcount enrolled exclusively in distance education courses, Percent of' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 11}
#
# page_content='of undergraduate 12-month unduplicated headcount enrolled in some but not all distance education courses, Percent of undergraduate 12-month unduplicated headcount not enrolled in any distance education courses, Percent of graduate 12-month unduplicated headcount enrolled exclusively in distance education courses, Percent of graduate 12-month unduplicated headcount enrolled in some but not all distance education courses, Percent of graduate 12-month unduplicated headcount not enrolled in any' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 12}
#
# page_content='in any distance education courses.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF122023.zip', 'input_type': 'drvef122023.csv', 'ptag_text_len': 5706, 'source': 'ipeds', 'source_idx': 7, 'source_idx_i': 13}
#
# page_content='CSV data file name: drvef2023.csv.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 0}
#
# page_content='Overview description of file contents: Table includes total full- and part-time enrollment: number of students by student level; percent of students by race/ethnicity categories for all students, undergraduate students and graduate students; percent of students enrolled in distance education courses; percent of undergraduate students by age groups; number of adult age (25-64) that are enrolled by level of student; percent of first-time students that are in-state, out-of-state, or from foreign' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 1}
#
# page_content='foreign countries;  Frequently used derived variables may include data for child campuses derived from allocation factors that are reported by the parent institution. Parent/child indicators can be found in table flags2023..' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 2}
#
# page_content='Data columns: Unique identification number of the institution, Total  enrollment, Full-time equivalent fall enrollment, Full-time enrollment, Part-time enrollment, Percent of total enrollment that are White, Percent of total enrollment that are Black or African American, Percent of total enrollment that are Hispanic/Latino, Percent of total enrollment that are Asian/Native Hawaiian/Pacific Islander, Percent of total enrollment that are Asian, Percent of total enrollment that are Native Hawaiian' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 3}
#
# page_content='Hawaiian or Other Pacific Islander, Percent of total enrollment that are American Indian or Alaska Native, Percent of total enrollment that are two or more races, Percent of total enrollment that are Race/ethnicity unknown, Percent of total enrollment that are U.S. Nonresident, Percent of total enrollment that are women, Full-time, first-time, degree/certificate seeking undergraduates (GRS Cohort) as percent of all undergraduates, Undergraduate enrollment, First-time degree/certificate-seeking' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 4}
#
# page_content='undergraduate enrollment, Transfer-in degree/certificate-seeking undergraduate enrollment, Continuing degree/certificate-seeking undergraduate enrollment, Nondegree/certificate-seeking undergraduate enrollment, Full-time undergraduate enrollment, Full-time first-time degree/certificate-seeking undergraduate enrollment, Full-time transfer-in degree/certificate-seeking undergraduate enrollment, Full-time continuing degree/certificate-seeking undergraduate enrollment, Full-time' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 5}
#
# page_content='Full-time nondegree/certificate-seeking undergraduate enrollment, Part-time undergraduate enrollment, Part-time first-time degree/certificate-seeking undergraduate enrollment, Part-time transfer-in degree/certificate-seeking undergraduate enrollment, Part-time continuing degree/certificate-seeking undergraduate enrollment, Part-time nondegree/certificate-seeking undergraduate enrollment, Percent of undergraduate enrollment that are White, Percent of undergraduate enrollment that are Black or' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 6}
#
# page_content='Black or African American, Percent of undergraduate enrollment that are Hispanic/Latino, Percent of undergraduate enrollment that are Asian/Native Hawaiian/Pacific Islander, Percent of undergraduate enrollment that are Asian, Percent of undergraduate enrollment that are Native Hawaiian or Other Pacific Islander, Percent of undergraduate enrollment that are American Indian or Alaska Native, Percent of undergraduate enrollment that are two or more races, Percent of undergraduate enrollment that' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 7}
#
# page_content='that are Race/ethnicity unknown, Percent of undergraduate enrollment that are U.S. Nonresident, Percent of undergraduate enrollment that are women, Graduate enrollment, Full-time graduate enrollment, Part-time graduate enrollment, Percent of graduate enrollment that are White, Percent of graduate enrollment that are Black or African American, Percent of graduate enrollment that are Hispanic/Latino, Percent of graduate enrollment that are Asian/Native Hawaiian/Pacific Islander, Percent of' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 8}
#
# page_content='of graduate enrollment that are Asian, Percent of graduate enrollment that are Native Hawaiian or Other Pacific Islander, Percent of graduate enrollment that are American Indian or Alaska Native, Percent of graduate enrollment that are two or more races, Percent of graduate enrollment that are Race/ethnicity unknown, Percent of graduate enrollment that are U.S. Nonresident, Percent of graduate enrollment that are women, Adult age (25-64) enrollment, all students, Adult age (25-64) enrollment,' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 9}
#
# page_content='undergraduate, Adult age (25-64) enrollment, graduate, Adult age (25-64) enrollment, full-time students, Adult age (25-64) enrollment, full-time undergraduate, Adult age (25-64) enrollment, full-time graduate, Adult age (25-64) enrollment, part-time students, Adult age (25-64) enrollment, part-time undergraduate, Adult age (25-64) enrollment, part-time graduate, Percent of undergraduate enrollment under 18, Percent of undergraduate enrollment 18-24, Percent of undergraduate enrollment, 25-64,' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 10}
#
# page_content='25-64, Percent of undergraduate enrollment over 65, Number of first-time undergraduates - in-state, Number of first-time undergraduates - out-of-state, Number of first-time undergraduates - foreign countries, Number of first-time undergraduates - residence unknown, Percent of first-time undergraduates - in-state, Percent of first-time undergraduates - out-of-state, Percent of first-time undergraduates - foreign countries, Percent of first-time undergraduates - residence unknown, Percent of' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 11}
#
# page_content='of students enrolled exclusively in distance education courses, Percent of students enrolled in some but not all distance education courses, Percent of students not enrolled in any distance education courses, Percent of undergraduate students enrolled exclusively in distance education courses, Percent of undergraduate students enrolled in some but not all distance education courses, Percent of undergraduate students not enrolled in any distance education courses, Percent of graduate students' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 12}
#
# page_content='students enrolled exclusively in distance education courses, Percent of graduate students enrolled in some but not all distance education courses, Percent of graduate students not enrolled in any distance education courses, Current year GRS cohort as a percent of entering class, Full-time retention rate, 2023, Part-time retention rate, 2023, Student-to-faculty ratio.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVEF2023.zip', 'input_type': 'drvef2023.csv', 'ptag_text_len': 6021, 'source': 'ipeds', 'source_idx': 8, 'source_idx_i': 13}
#
# page_content='CSV data file name: drvf2023.csv.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVF2023.zip', 'input_type': 'drvf2023.csv', 'ptag_text_len': 9133, 'source': 'ipeds', 'source_idx': 9, 'source_idx_i': 0}
#
# page_content='Overview description of file contents: Table includes the following financial indicator variables: percent of core revenues by source of revenue; percent of core expenses by expense functional categories; core revenues per full-time equivalent enrollment by source of revenues; core expenses per full-time equivalent enrollment by expense categories; expenses for salaries, wages, and benefits as a percent of total expenses, by expense categories;  There is a set of indicators for GASB, FASB and' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/DRVF2023.zip', 'input_type': 'drvf2023.csv', 'ptag_text_len': 9133, 'source': 'ipeds', 'source_idx': 9, 'source_idx_i': 1}
#
# ...
#
# page_content='grant and scholarship aid, all income levels, 2022-23, Total amount of grant and scholarship aid awarded, all income levels, 2022-23, Average amount of grant and scholarship aid awarded, all income levels, 2022-23, Number in income level (0-30,000), 2022-23, Number awarded grant and scholarship aid, income level (0-30,000), 2022-23, Total amount of grant and scholarship aid awarded, income level (0-30,000), 2022-23, Average amount of grant and scholarship aid awarded, income level (0-30,000),' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 45}
#
# page_content='2022-23, Number in income level (30,001-48,000), 2022-23, Number awarded grant and scholarship aid, income level (30,001-48,000), 2022-23, Total amount of grant and scholarship aid awarded, income level (30,001-48,000), 2022-23, Average amount of grant and scholarship aid awarded, income level (30,001-48,000), 2022-23, Number in income level (48,001-75,000), 2022-23, Number awarded grant and scholarship aid, income level (48,001-75,000), 2022-23, Total amount of grant and scholarship aid' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 46}
#
# page_content='aid awarded, income level (48,001-75,000), 2022-23, Average amount of grant and scholarship aid awarded, income level (48,001-75,000), 2022-23, Number in income level (75,001-110,000), 2022-23, Number awarded grant and scholarship aid, income level (75,001-110,000), 2022-23, Total amount of grant and scholarship aid awarded, income level (75,001-110,000), 2022-23, Average amount of grant and scholarship aid awarded, income level (75,001-110,000), 2022-23, Number in income level (110,001 or' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 47}
#
# page_content='or more), 2022-23, Number awarded grant and scholarship aid, income level (110,001 or more), 2022-23, Total amount of grant and scholarship aid awarded, income level (110,001 or more), 2022-23, Average amount of grant and scholarship aid awarded, income level (110,001 or more), 2022-23, Total number in all income levels, 2021-22, Number living on-campus in all income levels, 2021-22, Number living off-campus with family in all income levels, 2021-22, Number living off-campus not with family in' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 48}
#
# page_content='family in all income levels, 2021-22, Number living arrangement unknown in all income levels, 2021-22, Number awarded grant and scholarship aid, all income levels, 2021-22, Total amount of grant and scholarship aid awarded, all income levels, 2021-22, Average amount of grant and scholarship aid awarded, all income levels, 2021-22, Number in income level (0-30,000), 2021-22, Number awarded grant and scholarship aid, income level (0-30,000), 2021-22, Total amount of grant and scholarship aid' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 49}
#
# page_content='aid awarded, income level (0-30,000), 2021-22, Average amount of grant and scholarship aid awarded, income level (0-30,000), 2021-22, Number in income level (30,001-48,000), 2021-22, Number awarded grant and scholarship aid, income level (30,001-48,000), 2021-22, Total amount of grant and scholarship aid awarded, income level (30,001-48,000), 2021-22, Average amount of grant and scholarship aid awarded, income level (30,001-48,000), 2021-22, Number in income level (48,001-75,000), 2021-22,' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 50}
#
# page_content='2021-22, Number awarded grant and scholarship aid, income level (48,001-75,000), 2021-22, Total amount of grant and scholarship aid awarded, income level (48,001-75,000), 2021-22, Average amount of grant and scholarship aid awarded, income level (48,001-75,000), 2021-22, Number in income level (75,001-110,000), 2021-22, Number awarded grant and scholarship aid, income level (75,001-110,000), 2021-22, Total amount of grant and scholarship aid awarded, income level (75,001-110,000), 2021-22,' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 51}
#
# page_content='2021-22, Average amount of grant and scholarship aid awarded, income level (75,001-110,000), 2021-22, Number in income level (110,001 or more), 2021-22, Number awarded grant and scholarship aid, income level (110,001 or more), 2021-22, Total amount of grant and scholarship aid awarded, income level (110,001 or more), 2021-22, Average amount of grant and scholarship aid awarded, income level (110,001 or more), 2021-22, Total number in all income levels, 2020-21, Number living on-campus in all' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 52}
#
# page_content='in all income levels, 2020-21, Number living off-campus with family in all income levels, 2020-21, Number living off-campus not with family in all income levels, 2020-21, Number living arrangement unknown in all income levels, 2020-21, Number awarded grant and scholarship aid, all income levels, 2020-21, Total amount of grant and scholarship aid awarded, all income levels, 2020-21, Average amount of grant and scholarship aid awarded, all income levels, 2020-21, Number in income level' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 53}
#
# page_content='level (0-30,000), 2020-21, Number awarded grant and scholarship aid, income level (0-30,000), 2020-21, Total amount of grant and scholarship aid awarded, income level (0-30,000), 2020-21, Average amount of grant and scholarship aid awarded, income level (0-30,000), 2020-21, Number in income level (30,001-48,000), 2020-21, Number awarded grant and scholarship aid, income level (30,001-48,000), 2020-21, Total amount of grant and scholarship aid awarded, income level (30,001-48,000), 2020-21,' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 54}
#
# page_content='2020-21, Average amount of grant and scholarship aid awarded, income level (30,001-48,000), 2020-21, Number in income level (48,001-75,000), 2020-21, Number awarded grant and scholarship aid, income level (48,001-75,000), 2020-21, Total amount of grant and scholarship aid awarded, income level (48,001-75,000), 2020-21, Average amount of grant and scholarship aid awarded, income level (48,001-75,000), 2020-21, Number in income level (75,001-110,000), 2020-21, Number awarded grant and scholarship' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 55}
#
# page_content='aid, income level (75,001-110,000), 2020-21, Total amount of grant and scholarship aid awarded, income level (75,001-110,000), 2020-21, Average amount of grant and scholarship aid awarded, income level (75,001-110,000), 2020-21, Number in income level (110,001 or more), 2020-21, Number awarded grant and scholarship aid, income level (110,001 or more), 2020-21, Total amount of grant and scholarship aid awarded, income level (110,001 or more), 2020-21, Average amount of grant and scholarship aid' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 56}
#
# page_content='aid awarded, income level (110,001 or more), 2020-21, Average net price-students awarded grant or scholarship aid, 2022-23, Average net price-students awarded grant or scholarship aid, 2021-22, Average net price-students awarded grant or scholarship aid, 2020-21, Average net price (income 0-30,000)-students awarded Title IV federal financial aid, 2022-23, Average net price (income 30,001-48,000)-students awarded Title IV federal financial aid, 2022-23, Average net price (income' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 57}
#
# page_content='(income 48,001-75,000)-students awarded Title IV federal financial aid, 2022-23, Average net price (income 75,001-110,000)-students awarded Title IV federal financial aid, 2022-23, Average net price (income over 110,000)-students awarded Title IV federal financial aid, 2022-23, Average net price (income 0-30,000)-students awarded Title IV federal financial aid, 2021-22, Average net price (income 30,001-48,000)-students awarded Title IV federal financial aid, 2021-22, Average net price (income' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 58}
#
# page_content='(income 48,001-75,000)-students awarded Title IV federal financial aid, 2021-22, Average net price (income 75,001-110,000)-students awarded Title IV federal financial aid, 2021-22, Average net price (income over 110,000)-students awarded Title IV federal financial aid, 2021-22, Average net price (income 0-30,000)-students awarded Title IV federal financial aid, 2020-21, Average net price (income 30,001-48,000)-students awarded Title IV federal financial aid, 2020-21, Average net price (income' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 59}
#
# page_content='(income 48,001-75,000)-students awarded Title IV federal financial aid, 2020-21, Average net price (income 75,001-110,000)-students awarded Title IV federal financial aid, 2020-21, Average net price (income over 110,000)-students awarded Title IV federal financial aid, 2020-21.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFA2223.zip', 'input_type': 'sfa2223.csv', 'ptag_text_len': 28163, 'source': 'ipeds', 'source_idx': 39, 'source_idx_i': 60}
#
# page_content='CSV data file name: sfav2223.csv.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFAV2223.zip', 'input_type': 'sfav2223.csv', 'ptag_text_len': 2323, 'source': 'ipeds', 'source_idx': 40, 'source_idx_i': 0}
#
# page_content='Overview description of file contents: This file contains the number of students, who received either or both Post-9/11 GI Benefits or the Department of Defense Tuition Assistance through the institution. Eligible dependents receiving such benefits are included. Students who received both benefits, are counted in both programs. Total dollar amounts received by students are included. Data reported for the Post-9/11 GI Bill benefit are for the academic year July 1, 2022 to June 30, 2023.  Data' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFAV2223.zip', 'input_type': 'sfav2223.csv', 'ptag_text_len': 2323, 'source': 'ipeds', 'source_idx': 40, 'source_idx_i': 1}
#
# page_content='Data reported for the Department of Defense Tuition Assistance are for the academic year October 1, 2022 to September 30, 2023. Data are provided for undergraduate and graduate students..' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFAV2223.zip', 'input_type': 'sfav2223.csv', 'ptag_text_len': 2323, 'source': 'ipeds', 'source_idx': 40, 'source_idx_i': 2}
#
# page_content='Data columns: Unique identification number of the institution, Number receiving Post-9/11 GI Bill Benefits - undergraduate students, Total amount of Post-9/11 GI Bill Benefits awarded - undergraduate students, Average amount of Post-9/11 GI Bill Benefits awarded - undergraduate students, Number receiving Post-9/11 GI Bill Benefits - graduate students, Total amount of Post-9/11 GI Bill Benefits awarded - graduate students, Average amount of Post-9/11 GI Bill Benefits awarded - graduate students,' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFAV2223.zip', 'input_type': 'sfav2223.csv', 'ptag_text_len': 2323, 'source': 'ipeds', 'source_idx': 40, 'source_idx_i': 3}
#
# page_content='students, Number receiving Post-9/11 GI Bill Benefits - all students, Total amount of Post-9/11 GI Bill Benefits awarded - all students, Average amount of Post-9/11 GI Bill Benefits awarded - all students, Number receiving Department of Defense Tuition Assistance Program benefits - undergraduate students, Total amount of Department of Defense Tuition Assistance Program benefits  awarded - undergraduate students, Average amount of Department of Defense Tuition Assistance Program benefits' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFAV2223.zip', 'input_type': 'sfav2223.csv', 'ptag_text_len': 2323, 'source': 'ipeds', 'source_idx': 40, 'source_idx_i': 4}
#
# page_content='benefits awarded- undergraduate students, Number receiving Department of Defense Tuition Assistance Program benefits - graduate students, Total amount of Department of Defense Tuition Assistance Program benefits awarded - graduate students, Average amount of Department of Defense Tuition Assistance Program benefits awarded - graduate students, Number receiving Department of Defense Tuition Assistance Program benefits - all students, Total amount of Department of Defense Tuition Assistance' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFAV2223.zip', 'input_type': 'sfav2223.csv', 'ptag_text_len': 2323, 'source': 'ipeds', 'source_idx': 40, 'source_idx_i': 5}
#
# page_content='Program benefits awarded - all students, Average amount of Department of Defense Tuition Assistance Program benefits awarded - all students.' metadata={'seed_url': 'https://nces.ed.gov/ipeds', 'page_url': 'https://nces.ed.gov/ipeds/datacenter/data/SFAV2223.zip', 'input_type': 'sfav2223.csv', 'ptag_text_len': 2323, 'source': 'ipeds', 'source_idx': 40, 'source_idx_i': 6}

# %% [markdown]
# ## Test embeddings

# %%
# embed_loader.docs[-5:]

# mask = embed_loader.input_df["input_source"]=="tables_to_text"
# embed_loader.input_df[mask]
#
# len(embed_loader.input_df.loc[450,"ptag_text"])

# for doc in embed_loader.docs:
#     if doc.metadata == {'url': 'https://en.wikipedia.org/wiki/MiraCosta_College'}:
#         print(doc)
#         if doc.page_content.find("Center of Excellence in bioprocessing ")>=0:
#             print(doc.page_content)
# Out:
# [Document(metadata={'url': 'hifld_oes_wiki_ccccc', 'input_source': 'tables_to_text', 'id': 11336}, page_content='DE ANZA COLLEGE can be found online at : www.deanza.edu/'),
#  Document(metadata={'url': 'hifld_oes_wiki_ccccc', 'input_source': 'tables_to_text', 'id': 11337}, page_content='DE ANZA COLLEGE has total enrollment of 18649 students'),
#  Document(metadata={'url': 'hifld_oes_wiki_ccccc', 'input_source': 'tables_to_text', 'id': 11338}, page_content='DE ANZA COLLEGE does not have student housing'),
#  Document(metadata={'url': 'hifld_oes_wiki_ccccc', 'input_source': 'tables_to_text', 'id': 11339}, page_content='DE ANZA COLLEGE has the campuses of : DE ANZA COLLEGE CAMPUS'),
#  Document(metadata={'url': 'hifld_oes_wiki_ccccc', 'input_source': 'tables_to_text', 'id': 11340}, page_content='DE ANZA COLLEGE can be found on wikipedia at : en.wikipedia.org/wiki/De_Anza_College')]
